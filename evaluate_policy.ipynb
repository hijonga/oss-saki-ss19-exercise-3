# %% [markdown]
# # Reinforcement Learning

# %% [markdown]
# import necessary dependencies

# %%
! pip install pymdptoolbox
# Out:
# Requirement already satisfied: pymdptoolbox in /usr/local/lib/python3.6/dist-packages (4.0b3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from pymdptoolbox) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pymdptoolbox) (1.16.4)

# %%
import mdptoolbox
import numpy as np
import datetime
import csv
import pandas as pd

# %%
print(datetime.datetime.now())
# Out:
# 2019-07-09 20:25:51.307970

# %% [markdown]
# Load the drive folder

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.chdir("/content/gdrive/My Drive/SAKI_2019")

# %% [markdown]
# #### Get probability of different actions
# Get probability of commands from dataset

# %%
data = pd.read_csv("data/warehousetraining_2x3.txt", delimiter='\t', names=["instr", "next_color"])
length_data = len(data)
print(length_data)

df = data.copy()
df = df.groupby(["instr", "next_color"]).size().reset_index(name='probability') 
df['probability'] = df['probability'].div(length_data)
df['p'] = round(df['probability'],4)

if df.p.sum() != 1:
    print("rounding error sum of probabilities not 1")

print(df)
# Out:
# 12108
#      instr next_color  probability       p
# 0  restore       blue     0.125289  0.1253
# 1  restore        red     0.246862  0.2469
# 2  restore      white     0.127849  0.1278
# 3    store       blue     0.125289  0.1253
# 4    store        red     0.246862  0.2469
# 5    store      white     0.127849  0.1278

# %% [markdown]
# #### Initialize the states
# Get all possible states of the problem for the Marlov Decision process
#
# We put it all in a panda dataframe, to make it easier to work with

# %%
size_storage = 6
storage_places = range(1,(size_storage+1))
storage_state= ["0", "red", "blue", "white"] 
instr = ["store", "restore"]
next_color = ["red", "blue", "white"]


from itertools import product
if (size_storage == 4):
    states_tmp = pd.DataFrame(list(product(storage_state,storage_state,storage_state,storage_state, instr, next_color)), columns=['x1', 'x2', 'x3', 'x4', "instr", "next_color"])
elif (size_storage == 6):
    states_tmp = pd.DataFrame(list(product(storage_state,storage_state,storage_state,storage_state, storage_state,storage_state, instr, next_color)), columns=['x1', 'x2', 'x3', 'x4', 'x5', 'x6', "instr", "next_color"])
else:
    print ("Not supported storage size")
    
states = pd.merge(states_tmp,df, how = 'left' ,on = ["instr", "next_color"])

print (len(states))
print (states)
# Out:
# 24576
#           x1     x2     x3     x4  ...    instr next_color probability       p
# 0          0      0      0      0  ...    store        red    0.246862  0.2469
# 1          0      0      0      0  ...    store       blue    0.125289  0.1253
# 2          0      0      0      0  ...    store      white    0.127849  0.1278
# 3          0      0      0      0  ...  restore        red    0.246862  0.2469
# 4          0      0      0      0  ...  restore       blue    0.125289  0.1253
# 5          0      0      0      0  ...  restore      white    0.127849  0.1278
# 6          0      0      0      0  ...    store        red    0.246862  0.2469
# 7          0      0      0      0  ...    store       blue    0.125289  0.1253
# 8          0      0      0      0  ...    store      white    0.127849  0.1278
# 9          0      0      0      0  ...  restore        red    0.246862  0.2469
# 10         0      0      0      0  ...  restore       blue    0.125289  0.1253
# 11         0      0      0      0  ...  restore      white    0.127849  0.1278
# 12         0      0      0      0  ...    store        red    0.246862  0.2469
# 13         0      0      0      0  ...    store       blue    0.125289  0.1253
# 14         0      0      0      0  ...    store      white    0.127849  0.1278
# 15         0      0      0      0  ...  restore        red    0.246862  0.2469
# 16         0      0      0      0  ...  restore       blue    0.125289  0.1253
# 17         0      0      0      0  ...  restore      white    0.127849  0.1278
# 18         0      0      0      0  ...    store        red    0.246862  0.2469
# 19         0      0      0      0  ...    store       blue    0.125289  0.1253
# 20         0      0      0      0  ...    store      white    0.127849  0.1278
# 21         0      0      0      0  ...  restore        red    0.246862  0.2469
# 22         0      0      0      0  ...  restore       blue    0.125289  0.1253
# 23         0      0      0      0  ...  restore      white    0.127849  0.1278
# 24         0      0      0      0  ...    store        red    0.246862  0.2469
# 25         0      0      0      0  ...    store       blue    0.125289  0.1253
# 26         0      0      0      0  ...    store      white    0.127849  0.1278
# 27         0      0      0      0  ...  restore        red    0.246862  0.2469
# 28         0      0      0      0  ...  restore       blue    0.125289  0.1253
# 29         0      0      0      0  ...  restore      white    0.127849  0.1278
# ...      ...    ...    ...    ...  ...      ...        ...         ...     ...
# 24546  white  white  white  white  ...    store        red    0.246862  0.2469
# 24547  white  white  white  white  ...    store       blue    0.125289  0.1253
# 24548  white  white  white  white  ...    store      white    0.127849  0.1278
# 24549  white  white  white  white  ...  restore        red    0.246862  0.2469
# 24550  white  white  white  white  ...  restore       blue    0.125289  0.1253
# 24551  white  white  white  white  ...  restore      white    0.127849  0.1278
# 24552  white  white  white  white  ...    store        red    0.246862  0.2469
# 24553  white  white  white  white  ...    store       blue    0.125289  0.1253
# 24554  white  white  white  white  ...    store      white    0.127849  0.1278
# 24555  white  white  white  white  ...  restore        red    0.246862  0.2469
# 24556  white  white  white  white  ...  restore       blue    0.125289  0.1253
# 24557  white  white  white  white  ...  restore      white    0.127849  0.1278
# 24558  white  white  white  white  ...    store        red    0.246862  0.2469
# 24559  white  white  white  white  ...    store       blue    0.125289  0.1253
# 24560  white  white  white  white  ...    store      white    0.127849  0.1278
# 24561  white  white  white  white  ...  restore        red    0.246862  0.2469
# 24562  white  white  white  white  ...  restore       blue    0.125289  0.1253
# 24563  white  white  white  white  ...  restore      white    0.127849  0.1278
# 24564  white  white  white  white  ...    store        red    0.246862  0.2469
# 24565  white  white  white  white  ...    store       blue    0.125289  0.1253
# 24566  white  white  white  white  ...    store      white    0.127849  0.1278
# 24567  white  white  white  white  ...  restore        red    0.246862  0.2469
# 24568  white  white  white  white  ...  restore       blue    0.125289  0.1253
# 24569  white  white  white  white  ...  restore      white    0.127849  0.1278
# 24570  white  white  white  white  ...    store        red    0.246862  0.2469
# 24571  white  white  white  white  ...    store       blue    0.125289  0.1253
# 24572  white  white  white  white  ...    store      white    0.127849  0.1278
# 24573  white  white  white  white  ...  restore        red    0.246862  0.2469
# 24574  white  white  white  white  ...  restore       blue    0.125289  0.1253
# 24575  white  white  white  white  ...  restore      white    0.127849  0.1278
#
# [24576 rows x 10 columns]

# %%
start = datetime.datetime.now()
curr_state = ['0','0','0','0','0','0']
price = [-1,-2,-2,-3,-3,-4]
total_cost = 0
policy= np.load('Value_policy_2x3_10_10.npy')
not_possible_in = 0
not_possible_out = 0
no_storage = 0
no_restorage = 0

command = pd.read_csv("data/warehousetraining_2x3.txt", delimiter='\t', names=["instr", "next_color"])
print(len(command))

for move in command.itertuples():
   # print(move)#Pandas(Index=0, instr='store', next_color='red')
    df_pol = states
    
    #Where storage state is the same as current state
    for place in storage_places:
        df_pol = df_pol.loc[df_pol.iloc[ : , place-1]== str(curr_state[place-1])]
        
    # Where instructions and next colors are the same as in move
    print("command:" + move.instr +' '+ move.next_color)
    df_pol = df_pol.loc[df_pol['instr']== move.instr]
    df_pol = df_pol.loc[df_pol['next_color']== move.next_color]

    
    if len(df_pol.index) != 1:
        print ("ambigious variable")
    pol = policy[df_pol.index[0]]
    print(pol)
    total_cost = total_cost + price[pol]
    
    # update current state
    if move.instr == 'store':
        # punish not storing an item
        if (curr_state [pol] == move.next_color):
            print ('storage refused')
            no_storage =no_storage +1
            total_cost = total_cost + not_possible_in - price[pol]
        curr_state [pol] = move.next_color
    elif move.instr == 'restore':
        if(curr_state [pol] == '0'):
            print ('restorage not possible')
            no_restorage =no_restorage +1
            total_cost = total_cost + not_possible_out - price[pol]# test test
        curr_state [pol] = '0'
    
    print(total_cost)
    print(curr_state)
    
print('TOTAL COST:    ' + str(total_cost))
print(no_restorage)
print(no_storage)
print(datetime.datetime.now()-start)
# Out:
# 12108
# command:store red
# 0
# -1
# ['red', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -3
# ['red', 'blue', '0', '0', '0', '0']
# command:store white
# 2
# -5
# ['red', 'blue', 'white', '0', '0', '0']
# command:restore blue
# 1
# -7
# ['red', '0', 'white', '0', '0', '0']
# command:restore white
# 2
# -9
# ['red', '0', '0', '0', '0', '0']
# command:store white
# 1
# -11
# ['red', 'white', '0', '0', '0', '0']
# command:store red
# 2
# -13
# ['red', 'white', 'red', '0', '0', '0']
# command:store white
# 3
# -16
# ['red', 'white', 'red', 'white', '0', '0']
# command:store red
# 4
# -19
# ['red', 'white', 'red', 'white', 'red', '0']
# command:restore red
# 0
# -20
# ['0', 'white', 'red', 'white', 'red', '0']
# command:restore red
# 2
# -22
# ['0', 'white', '0', 'white', 'red', '0']
# command:store white
# 0
# -23
# ['white', 'white', '0', 'white', 'red', '0']
# command:store blue
# 2
# -25
# ['white', 'white', 'blue', 'white', 'red', '0']
# command:store white
# 0
# storage refused
# -25
# ['white', 'white', 'blue', 'white', 'red', '0']
# command:restore red
# 4
# -28
# ['white', 'white', 'blue', 'white', '0', '0']
# command:restore white
# 0
# -29
# ['0', 'white', 'blue', 'white', '0', '0']
# command:restore white
# 1
# -31
# ['0', '0', 'blue', 'white', '0', '0']
# command:store red
# 0
# -32
# ['red', '0', 'blue', 'white', '0', '0']
# command:store blue
# 4
# -35
# ['red', '0', 'blue', 'white', 'blue', '0']
# command:restore red
# 0
# -36
# ['0', '0', 'blue', 'white', 'blue', '0']
# command:store blue
# 5
# -40
# ['0', '0', 'blue', 'white', 'blue', 'blue']
# command:store white
# 0
# -41
# ['white', '0', 'blue', 'white', 'blue', 'blue']
# command:restore white
# 0
# -42
# ['0', '0', 'blue', 'white', 'blue', 'blue']
# command:restore blue
# 2
# -44
# ['0', '0', '0', 'white', 'blue', 'blue']
# command:restore white
# 3
# -47
# ['0', '0', '0', '0', 'blue', 'blue']
# command:restore white
# 0
# restorage not possible
# -47
# ['0', '0', '0', '0', 'blue', 'blue']
# command:restore blue
# 4
# -50
# ['0', '0', '0', '0', '0', 'blue']
# command:restore blue
# 5
# -54
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -55
# ['red', '0', '0', '0', '0', '0']
# command:restore red
# 0
# -56
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -57
# ['red', '0', '0', '0', '0', '0']
# command:store white
# 1
# -59
# ['red', 'white', '0', '0', '0', '0']
# command:store red
# 2
# -61
# ['red', 'white', 'red', '0', '0', '0']
# command:store red
# 3
# -64
# ['red', 'white', 'red', 'red', '0', '0']
# command:store white
# 4
# -67
# ['red', 'white', 'red', 'red', 'white', '0']
# command:store white
# 0
# -68
# ['white', 'white', 'red', 'red', 'white', '0']
# command:restore red
# 2
# -70
# ['white', 'white', '0', 'red', 'white', '0']
# command:restore red
# 3
# -73
# ['white', 'white', '0', '0', 'white', '0']
# command:restore red
# 0
# -74
# ['0', 'white', '0', '0', 'white', '0']
# command:store red
# 0
# -75
# ['red', 'white', '0', '0', 'white', '0']
# command:restore white
# 1
# -77
# ['red', '0', '0', '0', 'white', '0']
# command:restore red
# 0
# -78
# ['0', '0', '0', '0', 'white', '0']
# command:restore white
# 4
# -81
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -82
# ['red', '0', '0', '0', '0', '0']
# command:store red
# 1
# -84
# ['red', 'red', '0', '0', '0', '0']
# command:store white
# 2
# -86
# ['red', 'red', 'white', '0', '0', '0']
# command:store white
# 3
# -89
# ['red', 'red', 'white', 'white', '0', '0']
# command:store blue
# 4
# -92
# ['red', 'red', 'white', 'white', 'blue', '0']
# command:restore red
# 0
# -93
# ['0', 'red', 'white', 'white', 'blue', '0']
# command:restore red
# 1
# -95
# ['0', '0', 'white', 'white', 'blue', '0']
# command:restore white
# 2
# -97
# ['0', '0', '0', 'white', 'blue', '0']
# command:restore blue
# 4
# -100
# ['0', '0', '0', 'white', '0', '0']
# command:restore white
# 3
# -103
# ['0', '0', '0', '0', '0', '0']
# command:restore white
# 0
# restorage not possible
# -103
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -104
# ['blue', '0', '0', '0', '0', '0']
# command:store white
# 1
# -106
# ['blue', 'white', '0', '0', '0', '0']
# command:store white
# 3
# -109
# ['blue', 'white', '0', 'white', '0', '0']
# command:restore blue
# 0
# -110
# ['0', 'white', '0', 'white', '0', '0']
# command:restore white
# 1
# -112
# ['0', '0', '0', 'white', '0', '0']
# command:restore white
# 3
# -115
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -116
# ['white', '0', '0', '0', '0', '0']
# command:store white
# 1
# -118
# ['white', 'white', '0', '0', '0', '0']
# command:store blue
# 2
# -120
# ['white', 'white', 'blue', '0', '0', '0']
# command:store red
# 3
# -123
# ['white', 'white', 'blue', 'red', '0', '0']
# command:restore white
# 0
# -124
# ['0', 'white', 'blue', 'red', '0', '0']
# command:restore red
# 3
# -127
# ['0', 'white', 'blue', '0', '0', '0']
# command:restore white
# 1
# -129
# ['0', '0', 'blue', '0', '0', '0']
# command:restore blue
# 2
# -131
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -132
# ['white', '0', '0', '0', '0', '0']
# command:store red
# 1
# -134
# ['white', 'red', '0', '0', '0', '0']
# command:store red
# 2
# -136
# ['white', 'red', 'red', '0', '0', '0']
# command:restore red
# 1
# -138
# ['white', '0', 'red', '0', '0', '0']
# command:restore red
# 2
# -140
# ['white', '0', '0', '0', '0', '0']
# command:restore white
# 0
# -141
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -142
# ['blue', '0', '0', '0', '0', '0']
# command:store blue
# 3
# -145
# ['blue', '0', '0', 'blue', '0', '0']
# command:store red
# 1
# -147
# ['blue', 'red', '0', 'blue', '0', '0']
# command:store blue
# 5
# -151
# ['blue', 'red', '0', 'blue', '0', 'blue']
# command:store red
# 2
# -153
# ['blue', 'red', 'red', 'blue', '0', 'blue']
# command:store red
# 4
# -156
# ['blue', 'red', 'red', 'blue', 'red', 'blue']
# command:restore red
# 1
# -158
# ['blue', '0', 'red', 'blue', 'red', 'blue']
# command:restore red
# 2
# -160
# ['blue', '0', '0', 'blue', 'red', 'blue']
# command:restore red
# 4
# -163
# ['blue', '0', '0', 'blue', '0', 'blue']
# command:restore blue
# 0
# -164
# ['0', '0', '0', 'blue', '0', 'blue']
# command:store red
# 0
# -165
# ['red', '0', '0', 'blue', '0', 'blue']
# command:store red
# 1
# -167
# ['red', 'red', '0', 'blue', '0', 'blue']
# command:restore red
# 0
# -168
# ['0', 'red', '0', 'blue', '0', 'blue']
# command:restore red
# 1
# -170
# ['0', '0', '0', 'blue', '0', 'blue']
# command:restore blue
# 3
# -173
# ['0', '0', '0', '0', '0', 'blue']
# command:store white
# 0
# -174
# ['white', '0', '0', '0', '0', 'blue']
# command:store blue
# 1
# -176
# ['white', 'blue', '0', '0', '0', 'blue']
# command:restore white
# 0
# -177
# ['0', 'blue', '0', '0', '0', 'blue']
# command:store red
# 0
# -178
# ['red', 'blue', '0', '0', '0', 'blue']
# command:restore red
# 0
# -179
# ['0', 'blue', '0', '0', '0', 'blue']
# command:store white
# 0
# -180
# ['white', 'blue', '0', '0', '0', 'blue']
# command:restore blue
# 1
# -182
# ['white', '0', '0', '0', '0', 'blue']
# command:restore blue
# 5
# -186
# ['white', '0', '0', '0', '0', '0']
# command:restore white
# 0
# -187
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -188
# ['blue', '0', '0', '0', '0', '0']
# command:store red
# 1
# -190
# ['blue', 'red', '0', '0', '0', '0']
# command:store blue
# 3
# -193
# ['blue', 'red', '0', 'blue', '0', '0']
# command:store red
# 2
# -195
# ['blue', 'red', 'red', 'blue', '0', '0']
# command:restore red
# 1
# -197
# ['blue', '0', 'red', 'blue', '0', '0']
# command:restore red
# 2
# -199
# ['blue', '0', '0', 'blue', '0', '0']
# command:restore blue
# 0
# -200
# ['0', '0', '0', 'blue', '0', '0']
# command:store blue
# 0
# -201
# ['blue', '0', '0', 'blue', '0', '0']
# command:store white
# 1
# -203
# ['blue', 'white', '0', 'blue', '0', '0']
# command:store red
# 2
# -205
# ['blue', 'white', 'red', 'blue', '0', '0']
# command:store red
# 4
# -208
# ['blue', 'white', 'red', 'blue', 'red', '0']
# command:store red
# 5
# -212
# ['blue', 'white', 'red', 'blue', 'red', 'red']
# command:restore blue
# 0
# -213
# ['0', 'white', 'red', 'blue', 'red', 'red']
# command:restore red
# 2
# -215
# ['0', 'white', '0', 'blue', 'red', 'red']
# command:restore blue
# 3
# -218
# ['0', 'white', '0', '0', 'red', 'red']
# command:restore red
# 4
# -221
# ['0', 'white', '0', '0', '0', 'red']
# command:store blue
# 0
# -222
# ['blue', 'white', '0', '0', '0', 'red']
# command:store blue
# 3
# -225
# ['blue', 'white', '0', 'blue', '0', 'red']
# command:store blue
# 4
# -228
# ['blue', 'white', '0', 'blue', 'blue', 'red']
# command:restore red
# 5
# -232
# ['blue', 'white', '0', 'blue', 'blue', '0']
# command:restore white
# 1
# -234
# ['blue', '0', '0', 'blue', 'blue', '0']
# command:restore blue
# 0
# -235
# ['0', '0', '0', 'blue', 'blue', '0']
# command:store white
# 0
# -236
# ['white', '0', '0', 'blue', 'blue', '0']
# command:store blue
# 1
# -238
# ['white', 'blue', '0', 'blue', 'blue', '0']
# command:store blue
# 0
# -239
# ['blue', 'blue', '0', 'blue', 'blue', '0']
# command:restore blue
# 0
# -240
# ['0', 'blue', '0', 'blue', 'blue', '0']
# command:restore blue
# 1
# -242
# ['0', '0', '0', 'blue', 'blue', '0']
# command:restore white
# 0
# restorage not possible
# -242
# ['0', '0', '0', 'blue', 'blue', '0']
# command:store white
# 0
# -243
# ['white', '0', '0', 'blue', 'blue', '0']
# command:store white
# 1
# -245
# ['white', 'white', '0', 'blue', 'blue', '0']
# command:store red
# 2
# -247
# ['white', 'white', 'red', 'blue', 'blue', '0']
# command:restore blue
# 3
# -250
# ['white', 'white', 'red', '0', 'blue', '0']
# command:restore red
# 2
# -252
# ['white', 'white', '0', '0', 'blue', '0']
# command:store white
# 5
# -256
# ['white', 'white', '0', '0', 'blue', 'white']
# command:store white
# 0
# storage refused
# -256
# ['white', 'white', '0', '0', 'blue', 'white']
# command:store red
# 2
# -258
# ['white', 'white', 'red', '0', 'blue', 'white']
# command:restore red
# 2
# -260
# ['white', 'white', '0', '0', 'blue', 'white']
# command:restore blue
# 4
# -263
# ['white', 'white', '0', '0', '0', 'white']
# command:restore white
# 0
# -264
# ['0', 'white', '0', '0', '0', 'white']
# command:restore white
# 1
# -266
# ['0', '0', '0', '0', '0', 'white']
# command:restore white
# 5
# -270
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -271
# ['red', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -273
# ['red', 'blue', '0', '0', '0', '0']
# command:store white
# 2
# -275
# ['red', 'blue', 'white', '0', '0', '0']
# command:store red
# 3
# -278
# ['red', 'blue', 'white', 'red', '0', '0']
# command:restore red
# 0
# -279
# ['0', 'blue', 'white', 'red', '0', '0']
# command:restore red
# 3
# -282
# ['0', 'blue', 'white', '0', '0', '0']
# command:store red
# 0
# -283
# ['red', 'blue', 'white', '0', '0', '0']
# command:store white
# 3
# -286
# ['red', 'blue', 'white', 'white', '0', '0']
# command:store white
# 5
# -290
# ['red', 'blue', 'white', 'white', '0', 'white']
# command:restore white
# 2
# -292
# ['red', 'blue', '0', 'white', '0', 'white']
# command:restore red
# 0
# -293
# ['0', 'blue', '0', 'white', '0', 'white']
# command:restore blue
# 1
# -295
# ['0', '0', '0', 'white', '0', 'white']
# command:restore white
# 3
# -298
# ['0', '0', '0', '0', '0', 'white']
# command:restore white
# 5
# -302
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -303
# ['blue', '0', '0', '0', '0', '0']
# command:store blue
# 3
# -306
# ['blue', '0', '0', 'blue', '0', '0']
# command:store white
# 1
# -308
# ['blue', 'white', '0', 'blue', '0', '0']
# command:store red
# 2
# -310
# ['blue', 'white', 'red', 'blue', '0', '0']
# command:store red
# 4
# -313
# ['blue', 'white', 'red', 'blue', 'red', '0']
# command:restore white
# 1
# -315
# ['blue', '0', 'red', 'blue', 'red', '0']
# command:restore white
# 0
# -316
# ['0', '0', 'red', 'blue', 'red', '0']
# command:restore red
# 2
# -318
# ['0', '0', '0', 'blue', 'red', '0']
# command:restore red
# 4
# -321
# ['0', '0', '0', 'blue', '0', '0']
# command:store red
# 0
# -322
# ['red', '0', '0', 'blue', '0', '0']
# command:restore red
# 0
# -323
# ['0', '0', '0', 'blue', '0', '0']
# command:restore blue
# 3
# -326
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -327
# ['blue', '0', '0', '0', '0', '0']
# command:store red
# 1
# -329
# ['blue', 'red', '0', '0', '0', '0']
# command:restore red
# 1
# -331
# ['blue', '0', '0', '0', '0', '0']
# command:restore blue
# 0
# -332
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -333
# ['red', '0', '0', '0', '0', '0']
# command:store red
# 1
# -335
# ['red', 'red', '0', '0', '0', '0']
# command:store white
# 2
# -337
# ['red', 'red', 'white', '0', '0', '0']
# command:store red
# 3
# -340
# ['red', 'red', 'white', 'red', '0', '0']
# command:restore red
# 0
# -341
# ['0', 'red', 'white', 'red', '0', '0']
# command:restore red
# 1
# -343
# ['0', '0', 'white', 'red', '0', '0']
# command:restore blue
# 0
# restorage not possible
# -343
# ['0', '0', 'white', 'red', '0', '0']
# command:restore white
# 2
# -345
# ['0', '0', '0', 'red', '0', '0']
# command:restore red
# 3
# -348
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -349
# ['blue', '0', '0', '0', '0', '0']
# command:store red
# 1
# -351
# ['blue', 'red', '0', '0', '0', '0']
# command:store blue
# 3
# -354
# ['blue', 'red', '0', 'blue', '0', '0']
# command:store white
# 2
# -356
# ['blue', 'red', 'white', 'blue', '0', '0']
# command:restore red
# 1
# -358
# ['blue', '0', 'white', 'blue', '0', '0']
# command:restore white
# 2
# -360
# ['blue', '0', '0', 'blue', '0', '0']
# command:restore blue
# 0
# -361
# ['0', '0', '0', 'blue', '0', '0']
# command:store white
# 0
# -362
# ['white', '0', '0', 'blue', '0', '0']
# command:store blue
# 1
# -364
# ['white', 'blue', '0', 'blue', '0', '0']
# command:store red
# 2
# -366
# ['white', 'blue', 'red', 'blue', '0', '0']
# command:store white
# 4
# -369
# ['white', 'blue', 'red', 'blue', 'white', '0']
# command:store red
# 5
# -373
# ['white', 'blue', 'red', 'blue', 'white', 'red']
# command:restore red
# 2
# -375
# ['white', 'blue', '0', 'blue', 'white', 'red']
# command:restore red
# 5
# -379
# ['white', 'blue', '0', 'blue', 'white', '0']
# command:store red
# 2
# -381
# ['white', 'blue', 'red', 'blue', 'white', '0']
# command:store blue
# 0
# -382
# ['blue', 'blue', 'red', 'blue', 'white', '0']
# command:restore red
# 2
# -384
# ['blue', 'blue', '0', 'blue', 'white', '0']
# command:restore blue
# 0
# -385
# ['0', 'blue', '0', 'blue', 'white', '0']
# command:restore blue
# 1
# -387
# ['0', '0', '0', 'blue', 'white', '0']
# command:restore blue
# 3
# -390
# ['0', '0', '0', '0', 'white', '0']
# command:store red
# 0
# -391
# ['red', '0', '0', '0', 'white', '0']
# command:store white
# 1
# -393
# ['red', 'white', '0', '0', 'white', '0']
# command:restore white
# 1
# -395
# ['red', '0', '0', '0', 'white', '0']
# command:restore red
# 0
# -396
# ['0', '0', '0', '0', 'white', '0']
# command:restore white
# 4
# -399
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -400
# ['white', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -402
# ['white', 'blue', '0', '0', '0', '0']
# command:store white
# 3
# -405
# ['white', 'blue', '0', 'white', '0', '0']
# command:restore white
# 0
# -406
# ['0', 'blue', '0', 'white', '0', '0']
# command:restore blue
# 1
# -408
# ['0', '0', '0', 'white', '0', '0']
# command:restore white
# 3
# -411
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -412
# ['blue', '0', '0', '0', '0', '0']
# command:store blue
# 3
# -415
# ['blue', '0', '0', 'blue', '0', '0']
# command:store blue
# 1
# -417
# ['blue', 'blue', '0', 'blue', '0', '0']
# command:store red
# 2
# -419
# ['blue', 'blue', 'red', 'blue', '0', '0']
# command:restore white
# 0
# -420
# ['0', 'blue', 'red', 'blue', '0', '0']
# command:store red
# 0
# -421
# ['red', 'blue', 'red', 'blue', '0', '0']
# command:restore red
# 0
# -422
# ['0', 'blue', 'red', 'blue', '0', '0']
# command:restore red
# 2
# -424
# ['0', 'blue', '0', 'blue', '0', '0']
# command:restore blue
# 1
# -426
# ['0', '0', '0', 'blue', '0', '0']
# command:restore blue
# 3
# -429
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -430
# ['red', '0', '0', '0', '0', '0']
# command:store red
# 1
# -432
# ['red', 'red', '0', '0', '0', '0']
# command:store red
# 3
# -435
# ['red', 'red', '0', 'red', '0', '0']
# command:restore red
# 0
# -436
# ['0', 'red', '0', 'red', '0', '0']
# command:restore blue
# 0
# restorage not possible
# -436
# ['0', 'red', '0', 'red', '0', '0']
# command:restore red
# 1
# -438
# ['0', '0', '0', 'red', '0', '0']
# command:restore red
# 3
# -441
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -442
# ['red', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -444
# ['red', 'blue', '0', '0', '0', '0']
# command:store red
# 2
# -446
# ['red', 'blue', 'red', '0', '0', '0']
# command:store blue
# 3
# -449
# ['red', 'blue', 'red', 'blue', '0', '0']
# command:restore blue
# 1
# -451
# ['red', '0', 'red', 'blue', '0', '0']
# command:store blue
# 1
# -453
# ['red', 'blue', 'red', 'blue', '0', '0']
# command:store blue
# 5
# -457
# ['red', 'blue', 'red', 'blue', '0', 'blue']
# command:store red
# 4
# -460
# ['red', 'blue', 'red', 'blue', 'red', 'blue']
# command:restore blue
# 1
# -462
# ['red', '0', 'red', 'blue', 'red', 'blue']
# command:restore blue
# 3
# -465
# ['red', '0', 'red', '0', 'red', 'blue']
# command:store blue
# 1
# -467
# ['red', 'blue', 'red', '0', 'red', 'blue']
# command:store red
# 3
# -470
# ['red', 'blue', 'red', 'red', 'red', 'blue']
# command:restore red
# 0
# -471
# ['0', 'blue', 'red', 'red', 'red', 'blue']
# command:restore red
# 2
# -473
# ['0', 'blue', '0', 'red', 'red', 'blue']
# command:restore red
# 3
# -476
# ['0', 'blue', '0', '0', 'red', 'blue']
# command:restore red
# 4
# -479
# ['0', 'blue', '0', '0', '0', 'blue']
# command:store white
# 0
# -480
# ['white', 'blue', '0', '0', '0', 'blue']
# command:restore white
# 0
# -481
# ['0', 'blue', '0', '0', '0', 'blue']
# command:restore blue
# 1
# -483
# ['0', '0', '0', '0', '0', 'blue']
# command:restore blue
# 5
# -487
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -488
# ['blue', '0', '0', '0', '0', '0']
# command:store red
# 1
# -490
# ['blue', 'red', '0', '0', '0', '0']
# command:restore red
# 1
# -492
# ['blue', '0', '0', '0', '0', '0']
# command:store red
# 1
# -494
# ['blue', 'red', '0', '0', '0', '0']
# command:store red
# 2
# -496
# ['blue', 'red', 'red', '0', '0', '0']
# command:store red
# 3
# -499
# ['blue', 'red', 'red', 'red', '0', '0']
# command:store red
# 5
# -503
# ['blue', 'red', 'red', 'red', '0', 'red']
# command:store blue
# 4
# -506
# ['blue', 'red', 'red', 'red', 'blue', 'red']
# command:restore blue
# 0
# -507
# ['0', 'red', 'red', 'red', 'blue', 'red']
# command:restore red
# 1
# -509
# ['0', '0', 'red', 'red', 'blue', 'red']
# command:restore red
# 2
# -511
# ['0', '0', '0', 'red', 'blue', 'red']
# command:restore red
# 3
# -514
# ['0', '0', '0', '0', 'blue', 'red']
# command:restore red
# 5
# -518
# ['0', '0', '0', '0', 'blue', '0']
# command:restore blue
# 4
# -521
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -522
# ['white', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -524
# ['white', 'blue', '0', '0', '0', '0']
# command:store red
# 2
# -526
# ['white', 'blue', 'red', '0', '0', '0']
# command:store red
# 3
# -529
# ['white', 'blue', 'red', 'red', '0', '0']
# command:store red
# 4
# -532
# ['white', 'blue', 'red', 'red', 'red', '0']
# command:store blue
# 5
# -536
# ['white', 'blue', 'red', 'red', 'red', 'blue']
# command:restore white
# 0
# -537
# ['0', 'blue', 'red', 'red', 'red', 'blue']
# command:restore red
# 2
# -539
# ['0', 'blue', '0', 'red', 'red', 'blue']
# command:restore red
# 3
# -542
# ['0', 'blue', '0', '0', 'red', 'blue']
# command:store red
# 0
# -543
# ['red', 'blue', '0', '0', 'red', 'blue']
# command:store white
# 2
# -545
# ['red', 'blue', 'white', '0', 'red', 'blue']
# command:store white
# 3
# -548
# ['red', 'blue', 'white', 'white', 'red', 'blue']
# command:restore red
# 0
# -549
# ['0', 'blue', 'white', 'white', 'red', 'blue']
# command:restore blue
# 1
# -551
# ['0', '0', 'white', 'white', 'red', 'blue']
# command:restore white
# 2
# -553
# ['0', '0', '0', 'white', 'red', 'blue']
# command:restore red
# 4
# -556
# ['0', '0', '0', 'white', '0', 'blue']
# command:restore white
# 3
# -559
# ['0', '0', '0', '0', '0', 'blue']
# command:restore blue
# 5
# -563
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -564
# ['white', '0', '0', '0', '0', '0']
# command:restore white
# 0
# -565
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -566
# ['white', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -568
# ['white', 'blue', '0', '0', '0', '0']
# command:restore blue
# 1
# -570
# ['white', '0', '0', '0', '0', '0']
# command:restore white
# 0
# -571
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -572
# ['blue', '0', '0', '0', '0', '0']
# command:store blue
# 3
# -575
# ['blue', '0', '0', 'blue', '0', '0']
# command:store blue
# 1
# -577
# ['blue', 'blue', '0', 'blue', '0', '0']
# command:store blue
# 0
# storage refused
# -577
# ['blue', 'blue', '0', 'blue', '0', '0']
# command:restore blue
# 0
# -578
# ['0', 'blue', '0', 'blue', '0', '0']
# command:store white
# 0
# -579
# ['white', 'blue', '0', 'blue', '0', '0']
# command:restore white
# 0
# -580
# ['0', 'blue', '0', 'blue', '0', '0']
# command:restore blue
# 1
# -582
# ['0', '0', '0', 'blue', '0', '0']
# command:restore blue
# 3
# -585
# ['0', '0', '0', '0', '0', '0']
# command:restore blue
# 0
# restorage not possible
# -585
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -586
# ['white', '0', '0', '0', '0', '0']
# command:restore white
# 0
# -587
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -588
# ['white', '0', '0', '0', '0', '0']
# command:store red
# 1
# -590
# ['white', 'red', '0', '0', '0', '0']
# command:store blue
# 2
# -592
# ['white', 'red', 'blue', '0', '0', '0']
# command:store blue
# 3
# -595
# ['white', 'red', 'blue', 'blue', '0', '0']
# command:restore red
# 1
# -597
# ['white', '0', 'blue', 'blue', '0', '0']
# command:restore blue
# 2
# -599
# ['white', '0', '0', 'blue', '0', '0']
# command:restore blue
# 3
# -602
# ['white', '0', '0', '0', '0', '0']
# command:restore white
# 0
# -603
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -604
# ['red', '0', '0', '0', '0', '0']
# command:store red
# 1
# -606
# ['red', 'red', '0', '0', '0', '0']
# command:restore red
# 0
# -607
# ['0', 'red', '0', '0', '0', '0']
# command:store red
# 0
# -608
# ['red', 'red', '0', '0', '0', '0']
# command:store white
# 2
# -610
# ['red', 'red', 'white', '0', '0', '0']
# command:store white
# 3
# -613
# ['red', 'red', 'white', 'white', '0', '0']
# command:store red
# 4
# -616
# ['red', 'red', 'white', 'white', 'red', '0']
# command:restore white
# 2
# -618
# ['red', 'red', '0', 'white', 'red', '0']
# command:restore white
# 3
# -621
# ['red', 'red', '0', '0', 'red', '0']
# command:restore red
# 0
# -622
# ['0', 'red', '0', '0', 'red', '0']
# command:store red
# 0
# -623
# ['red', 'red', '0', '0', 'red', '0']
# command:store blue
# 2
# -625
# ['red', 'red', 'blue', '0', 'red', '0']
# command:store red
# 5
# -629
# ['red', 'red', 'blue', '0', 'red', 'red']
# command:restore red
# 0
# -630
# ['0', 'red', 'blue', '0', 'red', 'red']
# command:restore red
# 1
# -632
# ['0', '0', 'blue', '0', 'red', 'red']
# command:restore blue
# 2
# -634
# ['0', '0', '0', '0', 'red', 'red']
# command:restore red
# 4
# -637
# ['0', '0', '0', '0', '0', 'red']
# command:restore red
# 5
# -641
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -642
# ['white', '0', '0', '0', '0', '0']
# command:store white
# 1
# -644
# ['white', 'white', '0', '0', '0', '0']
# command:store red
# 2
# -646
# ['white', 'white', 'red', '0', '0', '0']
# command:restore white
# 0
# -647
# ['0', 'white', 'red', '0', '0', '0']
# command:restore red
# 2
# -649
# ['0', 'white', '0', '0', '0', '0']
# command:restore white
# 1
# -651
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -652
# ['red', '0', '0', '0', '0', '0']
# command:store red
# 1
# -654
# ['red', 'red', '0', '0', '0', '0']
# command:store blue
# 2
# -656
# ['red', 'red', 'blue', '0', '0', '0']
# command:store white
# 3
# -659
# ['red', 'red', 'blue', 'white', '0', '0']
# command:store red
# 4
# -662
# ['red', 'red', 'blue', 'white', 'red', '0']
# command:restore red
# 0
# -663
# ['0', 'red', 'blue', 'white', 'red', '0']
# command:restore blue
# 2
# -665
# ['0', 'red', '0', 'white', 'red', '0']
# command:restore red
# 1
# -667
# ['0', '0', '0', 'white', 'red', '0']
# command:store red
# 0
# -668
# ['red', '0', '0', 'white', 'red', '0']
# command:store white
# 1
# -670
# ['red', 'white', '0', 'white', 'red', '0']
# command:restore red
# 0
# -671
# ['0', 'white', '0', 'white', 'red', '0']
# command:store white
# 0
# -672
# ['white', 'white', '0', 'white', 'red', '0']
# command:store red
# 2
# -674
# ['white', 'white', 'red', 'white', 'red', '0']
# command:store blue
# 5
# -678
# ['white', 'white', 'red', 'white', 'red', 'blue']
# command:restore blue
# 5
# -682
# ['white', 'white', 'red', 'white', 'red', '0']
# command:store red
# 5
# -686
# ['white', 'white', 'red', 'white', 'red', 'red']
# command:restore red
# 2
# -688
# ['white', 'white', '0', 'white', 'red', 'red']
# command:restore white
# 0
# -689
# ['0', 'white', '0', 'white', 'red', 'red']
# command:restore red
# 4
# -692
# ['0', 'white', '0', 'white', '0', 'red']
# command:restore red
# 5
# -696
# ['0', 'white', '0', 'white', '0', '0']
# command:restore white
# 1
# -698
# ['0', '0', '0', 'white', '0', '0']
# command:restore white
# 3
# -701
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -702
# ['white', '0', '0', '0', '0', '0']
# command:store red
# 1
# -704
# ['white', 'red', '0', '0', '0', '0']
# command:store red
# 2
# -706
# ['white', 'red', 'red', '0', '0', '0']
# command:store red
# 3
# -709
# ['white', 'red', 'red', 'red', '0', '0']
# command:restore red
# 1
# -711
# ['white', '0', 'red', 'red', '0', '0']
# command:restore red
# 2
# -713
# ['white', '0', '0', 'red', '0', '0']
# command:restore white
# 0
# -714
# ['0', '0', '0', 'red', '0', '0']
# command:restore red
# 3
# -717
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -718
# ['red', '0', '0', '0', '0', '0']
# command:store red
# 1
# -720
# ['red', 'red', '0', '0', '0', '0']
# command:restore red
# 0
# -721
# ['0', 'red', '0', '0', '0', '0']
# command:restore red
# 1
# -723
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -724
# ['red', '0', '0', '0', '0', '0']
# command:store red
# 1
# -726
# ['red', 'red', '0', '0', '0', '0']
# command:store red
# 3
# -729
# ['red', 'red', '0', 'red', '0', '0']
# command:store red
# 5
# -733
# ['red', 'red', '0', 'red', '0', 'red']
# command:store red
# 2
# -735
# ['red', 'red', 'red', 'red', '0', 'red']
# command:store red
# 0
# storage refused
# -735
# ['red', 'red', 'red', 'red', '0', 'red']
# command:restore red
# 0
# -736
# ['0', 'red', 'red', 'red', '0', 'red']
# command:restore red
# 1
# -738
# ['0', '0', 'red', 'red', '0', 'red']
# command:restore red
# 2
# -740
# ['0', '0', '0', 'red', '0', 'red']
# command:restore red
# 3
# -743
# ['0', '0', '0', '0', '0', 'red']
# command:store white
# 0
# -744
# ['white', '0', '0', '0', '0', 'red']
# command:store blue
# 1
# -746
# ['white', 'blue', '0', '0', '0', 'red']
# command:store red
# 2
# -748
# ['white', 'blue', 'red', '0', '0', 'red']
# command:restore white
# 0
# -749
# ['0', 'blue', 'red', '0', '0', 'red']
# command:restore blue
# 1
# -751
# ['0', '0', 'red', '0', '0', 'red']
# command:restore red
# 2
# -753
# ['0', '0', '0', '0', '0', 'red']
# command:restore red
# 5
# -757
# ['0', '0', '0', '0', '0', '0']
# command:restore red
# 0
# restorage not possible
# -757
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -758
# ['red', '0', '0', '0', '0', '0']
# command:restore red
# 0
# -759
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -760
# ['red', '0', '0', '0', '0', '0']
# command:store red
# 1
# -762
# ['red', 'red', '0', '0', '0', '0']
# command:restore red
# 0
# -763
# ['0', 'red', '0', '0', '0', '0']
# command:store red
# 0
# -764
# ['red', 'red', '0', '0', '0', '0']
# command:store blue
# 2
# -766
# ['red', 'red', 'blue', '0', '0', '0']
# command:restore blue
# 2
# -768
# ['red', 'red', '0', '0', '0', '0']
# command:restore red
# 0
# -769
# ['0', 'red', '0', '0', '0', '0']
# command:store red
# 0
# -770
# ['red', 'red', '0', '0', '0', '0']
# command:store blue
# 2
# -772
# ['red', 'red', 'blue', '0', '0', '0']
# command:store blue
# 3
# -775
# ['red', 'red', 'blue', 'blue', '0', '0']
# command:store red
# 4
# -778
# ['red', 'red', 'blue', 'blue', 'red', '0']
# command:store red
# 5
# -782
# ['red', 'red', 'blue', 'blue', 'red', 'red']
# command:restore red
# 0
# -783
# ['0', 'red', 'blue', 'blue', 'red', 'red']
# command:restore red
# 1
# -785
# ['0', '0', 'blue', 'blue', 'red', 'red']
# command:restore blue
# 2
# -787
# ['0', '0', '0', 'blue', 'red', 'red']
# command:restore red
# 4
# -790
# ['0', '0', '0', 'blue', '0', 'red']
# command:store red
# 0
# -791
# ['red', '0', '0', 'blue', '0', 'red']
# command:store red
# 1
# -793
# ['red', 'red', '0', 'blue', '0', 'red']
# command:store red
# 4
# -796
# ['red', 'red', '0', 'blue', 'red', 'red']
# command:restore red
# 0
# -797
# ['0', 'red', '0', 'blue', 'red', 'red']
# command:restore red
# 1
# -799
# ['0', '0', '0', 'blue', 'red', 'red']
# command:restore red
# 4
# -802
# ['0', '0', '0', 'blue', '0', 'red']
# command:restore red
# 5
# -806
# ['0', '0', '0', 'blue', '0', '0']
# command:restore blue
# 3
# -809
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -810
# ['blue', '0', '0', '0', '0', '0']
# command:store red
# 1
# -812
# ['blue', 'red', '0', '0', '0', '0']
# command:store white
# 2
# -814
# ['blue', 'red', 'white', '0', '0', '0']
# command:store red
# 3
# -817
# ['blue', 'red', 'white', 'red', '0', '0']
# command:restore red
# 1
# -819
# ['blue', '0', 'white', 'red', '0', '0']
# command:restore red
# 3
# -822
# ['blue', '0', 'white', '0', '0', '0']
# command:restore blue
# 0
# -823
# ['0', '0', 'white', '0', '0', '0']
# command:store red
# 0
# -824
# ['red', '0', 'white', '0', '0', '0']
# command:store white
# 3
# -827
# ['red', '0', 'white', 'white', '0', '0']
# command:store red
# 1
# -829
# ['red', 'red', 'white', 'white', '0', '0']
# command:restore red
# 0
# -830
# ['0', 'red', 'white', 'white', '0', '0']
# command:store red
# 0
# -831
# ['red', 'red', 'white', 'white', '0', '0']
# command:store red
# 4
# -834
# ['red', 'red', 'white', 'white', 'red', '0']
# command:store white
# 0
# -835
# ['white', 'red', 'white', 'white', 'red', '0']
# command:restore white
# 0
# -836
# ['0', 'red', 'white', 'white', 'red', '0']
# command:restore red
# 1
# -838
# ['0', '0', 'white', 'white', 'red', '0']
# command:restore white
# 2
# -840
# ['0', '0', '0', 'white', 'red', '0']
# command:restore red
# 4
# -843
# ['0', '0', '0', 'white', '0', '0']
# command:store red
# 0
# -844
# ['red', '0', '0', 'white', '0', '0']
# command:restore red
# 0
# -845
# ['0', '0', '0', 'white', '0', '0']
# command:restore red
# 0
# restorage not possible
# -845
# ['0', '0', '0', 'white', '0', '0']
# command:restore white
# 3
# -848
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -849
# ['white', '0', '0', '0', '0', '0']
# command:store red
# 1
# -851
# ['white', 'red', '0', '0', '0', '0']
# command:store blue
# 2
# -853
# ['white', 'red', 'blue', '0', '0', '0']
# command:store red
# 3
# -856
# ['white', 'red', 'blue', 'red', '0', '0']
# command:store white
# 4
# -859
# ['white', 'red', 'blue', 'red', 'white', '0']
# command:restore red
# 1
# -861
# ['white', '0', 'blue', 'red', 'white', '0']
# command:restore blue
# 2
# -863
# ['white', '0', '0', 'red', 'white', '0']
# command:restore white
# 0
# -864
# ['0', '0', '0', 'red', 'white', '0']
# command:store red
# 0
# -865
# ['red', '0', '0', 'red', 'white', '0']
# command:store blue
# 1
# -867
# ['red', 'blue', '0', 'red', 'white', '0']
# command:store red
# 2
# -869
# ['red', 'blue', 'red', 'red', 'white', '0']
# command:restore white
# 4
# -872
# ['red', 'blue', 'red', 'red', '0', '0']
# command:restore red
# 0
# -873
# ['0', 'blue', 'red', 'red', '0', '0']
# command:restore red
# 2
# -875
# ['0', 'blue', '0', 'red', '0', '0']
# command:restore blue
# 1
# -877
# ['0', '0', '0', 'red', '0', '0']
# command:restore red
# 3
# -880
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -881
# ['white', '0', '0', '0', '0', '0']
# command:store white
# 1
# -883
# ['white', 'white', '0', '0', '0', '0']
# command:store blue
# 2
# -885
# ['white', 'white', 'blue', '0', '0', '0']
# command:store red
# 3
# -888
# ['white', 'white', 'blue', 'red', '0', '0']
# command:store red
# 4
# -891
# ['white', 'white', 'blue', 'red', 'red', '0']
# command:store white
# 5
# -895
# ['white', 'white', 'blue', 'red', 'red', 'white']
# command:restore red
# 3
# -898
# ['white', 'white', 'blue', '0', 'red', 'white']
# command:store red
# 3
# -901
# ['white', 'white', 'blue', 'red', 'red', 'white']
# command:restore red
# 3
# -904
# ['white', 'white', 'blue', '0', 'red', 'white']
# command:restore blue
# 2
# -906
# ['white', 'white', '0', '0', 'red', 'white']
# command:store blue
# 2
# -908
# ['white', 'white', 'blue', '0', 'red', 'white']
# command:store red
# 3
# -911
# ['white', 'white', 'blue', 'red', 'red', 'white']
# command:restore red
# 3
# -914
# ['white', 'white', 'blue', '0', 'red', 'white']
# command:restore red
# 4
# -917
# ['white', 'white', 'blue', '0', '0', 'white']
# command:restore blue
# 2
# -919
# ['white', 'white', '0', '0', '0', 'white']
# command:store red
# 2
# -921
# ['white', 'white', 'red', '0', '0', 'white']
# command:store red
# 3
# -924
# ['white', 'white', 'red', 'red', '0', 'white']
# command:store blue
# 4
# -927
# ['white', 'white', 'red', 'red', 'blue', 'white']
# command:restore red
# 2
# -929
# ['white', 'white', '0', 'red', 'blue', 'white']
# command:restore blue
# 4
# -932
# ['white', 'white', '0', 'red', '0', 'white']
# command:restore red
# 3
# -935
# ['white', 'white', '0', '0', '0', 'white']
# command:restore white
# 0
# -936
# ['0', 'white', '0', '0', '0', 'white']
# command:restore white
# 1
# -938
# ['0', '0', '0', '0', '0', 'white']
# command:restore white
# 5
# -942
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -943
# ['blue', '0', '0', '0', '0', '0']
# command:store red
# 1
# -945
# ['blue', 'red', '0', '0', '0', '0']
# command:store blue
# 3
# -948
# ['blue', 'red', '0', 'blue', '0', '0']
# command:store white
# 2
# -950
# ['blue', 'red', 'white', 'blue', '0', '0']
# command:restore red
# 1
# -952
# ['blue', '0', 'white', 'blue', '0', '0']
# command:restore white
# 2
# -954
# ['blue', '0', '0', 'blue', '0', '0']
# command:restore blue
# 0
# -955
# ['0', '0', '0', 'blue', '0', '0']
# command:restore blue
# 3
# -958
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -959
# ['blue', '0', '0', '0', '0', '0']
# command:store red
# 1
# -961
# ['blue', 'red', '0', '0', '0', '0']
# command:store red
# 2
# -963
# ['blue', 'red', 'red', '0', '0', '0']
# command:store white
# 3
# -966
# ['blue', 'red', 'red', 'white', '0', '0']
# command:store blue
# 4
# -969
# ['blue', 'red', 'red', 'white', 'blue', '0']
# command:restore blue
# 0
# -970
# ['0', 'red', 'red', 'white', 'blue', '0']
# command:store blue
# 0
# -971
# ['blue', 'red', 'red', 'white', 'blue', '0']
# command:store red
# 5
# -975
# ['blue', 'red', 'red', 'white', 'blue', 'red']
# command:restore blue
# 0
# -976
# ['0', 'red', 'red', 'white', 'blue', 'red']
# command:restore red
# 1
# -978
# ['0', '0', 'red', 'white', 'blue', 'red']
# command:restore white
# 3
# -981
# ['0', '0', 'red', '0', 'blue', 'red']
# command:restore blue
# 4
# -984
# ['0', '0', 'red', '0', '0', 'red']
# command:restore red
# 2
# -986
# ['0', '0', '0', '0', '0', 'red']
# command:restore red
# 5
# -990
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -991
# ['red', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -993
# ['red', 'blue', '0', '0', '0', '0']
# command:store white
# 2
# -995
# ['red', 'blue', 'white', '0', '0', '0']
# command:restore red
# 0
# -996
# ['0', 'blue', 'white', '0', '0', '0']
# command:restore blue
# 1
# -998
# ['0', '0', 'white', '0', '0', '0']
# command:store blue
# 0
# -999
# ['blue', '0', 'white', '0', '0', '0']
# command:store blue
# 3
# -1002
# ['blue', '0', 'white', 'blue', '0', '0']
# command:restore blue
# 0
# -1003
# ['0', '0', 'white', 'blue', '0', '0']
# command:restore blue
# 3
# -1006
# ['0', '0', 'white', '0', '0', '0']
# command:restore white
# 2
# -1008
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -1009
# ['white', '0', '0', '0', '0', '0']
# command:store red
# 1
# -1011
# ['white', 'red', '0', '0', '0', '0']
# command:store red
# 2
# -1013
# ['white', 'red', 'red', '0', '0', '0']
# command:store red
# 3
# -1016
# ['white', 'red', 'red', 'red', '0', '0']
# command:store red
# 5
# -1020
# ['white', 'red', 'red', 'red', '0', 'red']
# command:restore red
# 1
# -1022
# ['white', '0', 'red', 'red', '0', 'red']
# command:store white
# 4
# -1025
# ['white', '0', 'red', 'red', 'white', 'red']
# command:store blue
# 1
# -1027
# ['white', 'blue', 'red', 'red', 'white', 'red']
# command:restore white
# 0
# -1028
# ['0', 'blue', 'red', 'red', 'white', 'red']
# command:restore red
# 2
# -1030
# ['0', 'blue', '0', 'red', 'white', 'red']
# command:restore red
# 3
# -1033
# ['0', 'blue', '0', '0', 'white', 'red']
# command:store red
# 0
# -1034
# ['red', 'blue', '0', '0', 'white', 'red']
# command:store red
# 2
# -1036
# ['red', 'blue', 'red', '0', 'white', 'red']
# command:restore red
# 0
# -1037
# ['0', 'blue', 'red', '0', 'white', 'red']
# command:restore red
# 2
# -1039
# ['0', 'blue', '0', '0', 'white', 'red']
# command:restore red
# 5
# -1043
# ['0', 'blue', '0', '0', 'white', '0']
# command:restore white
# 4
# -1046
# ['0', 'blue', '0', '0', '0', '0']
# command:restore blue
# 1
# -1048
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -1049
# ['red', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -1051
# ['red', 'blue', '0', '0', '0', '0']
# command:store red
# 2
# -1053
# ['red', 'blue', 'red', '0', '0', '0']
# command:store blue
# 3
# -1056
# ['red', 'blue', 'red', 'blue', '0', '0']
# command:store white
# 4
# -1059
# ['red', 'blue', 'red', 'blue', 'white', '0']
# command:store blue
# 0
# -1060
# ['blue', 'blue', 'red', 'blue', 'white', '0']
# command:restore red
# 2
# -1062
# ['blue', 'blue', '0', 'blue', 'white', '0']
# command:restore red
# 0
# -1063
# ['0', 'blue', '0', 'blue', 'white', '0']
# command:store red
# 0
# -1064
# ['red', 'blue', '0', 'blue', 'white', '0']
# command:restore red
# 0
# -1065
# ['0', 'blue', '0', 'blue', 'white', '0']
# command:restore white
# 4
# -1068
# ['0', 'blue', '0', 'blue', '0', '0']
# command:restore blue
# 1
# -1070
# ['0', '0', '0', 'blue', '0', '0']
# command:restore blue
# 3
# -1073
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -1074
# ['white', '0', '0', '0', '0', '0']
# command:store white
# 1
# -1076
# ['white', 'white', '0', '0', '0', '0']
# command:store blue
# 2
# -1078
# ['white', 'white', 'blue', '0', '0', '0']
# command:store white
# 3
# -1081
# ['white', 'white', 'blue', 'white', '0', '0']
# command:restore blue
# 2
# -1083
# ['white', 'white', '0', 'white', '0', '0']
# command:restore blue
# 0
# -1084
# ['0', 'white', '0', 'white', '0', '0']
# command:restore white
# 1
# -1086
# ['0', '0', '0', 'white', '0', '0']
# command:restore white
# 3
# -1089
# ['0', '0', '0', '0', '0', '0']
# command:restore white
# 0
# restorage not possible
# -1089
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -1090
# ['blue', '0', '0', '0', '0', '0']
# command:store blue
# 3
# -1093
# ['blue', '0', '0', 'blue', '0', '0']
# command:store white
# 1
# -1095
# ['blue', 'white', '0', 'blue', '0', '0']
# command:store white
# 4
# -1098
# ['blue', 'white', '0', 'blue', 'white', '0']
# command:restore blue
# 0
# -1099
# ['0', 'white', '0', 'blue', 'white', '0']
# command:restore blue
# 3
# -1102
# ['0', 'white', '0', '0', 'white', '0']
# command:store white
# 0
# -1103
# ['white', 'white', '0', '0', 'white', '0']
# command:store white
# 0
# storage refused
# -1103
# ['white', 'white', '0', '0', 'white', '0']
# command:store red
# 2
# -1105
# ['white', 'white', 'red', '0', 'white', '0']
# command:store red
# 3
# -1108
# ['white', 'white', 'red', 'red', 'white', '0']
# command:restore white
# 0
# -1109
# ['0', 'white', 'red', 'red', 'white', '0']
# command:restore white
# 1
# -1111
# ['0', '0', 'red', 'red', 'white', '0']
# command:restore red
# 2
# -1113
# ['0', '0', '0', 'red', 'white', '0']
# command:restore red
# 3
# -1116
# ['0', '0', '0', '0', 'white', '0']
# command:store white
# 0
# -1117
# ['white', '0', '0', '0', 'white', '0']
# command:store red
# 1
# -1119
# ['white', 'red', '0', '0', 'white', '0']
# command:store white
# 3
# -1122
# ['white', 'red', '0', 'white', 'white', '0']
# command:store white
# 0
# storage refused
# -1122
# ['white', 'red', '0', 'white', 'white', '0']
# command:restore white
# 0
# -1123
# ['0', 'red', '0', 'white', 'white', '0']
# command:restore red
# 1
# -1125
# ['0', '0', '0', 'white', 'white', '0']
# command:restore white
# 3
# -1128
# ['0', '0', '0', '0', 'white', '0']
# command:store white
# 0
# -1129
# ['white', '0', '0', '0', 'white', '0']
# command:store red
# 1
# -1131
# ['white', 'red', '0', '0', 'white', '0']
# command:store red
# 2
# -1133
# ['white', 'red', 'red', '0', 'white', '0']
# command:restore red
# 1
# -1135
# ['white', '0', 'red', '0', 'white', '0']
# command:store red
# 1
# -1137
# ['white', 'red', 'red', '0', 'white', '0']
# command:restore red
# 1
# -1139
# ['white', '0', 'red', '0', 'white', '0']
# command:restore red
# 2
# -1141
# ['white', '0', '0', '0', 'white', '0']
# command:restore white
# 0
# -1142
# ['0', '0', '0', '0', 'white', '0']
# command:restore white
# 4
# -1145
# ['0', '0', '0', '0', '0', '0']
# command:restore white
# 0
# restorage not possible
# -1145
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -1146
# ['blue', '0', '0', '0', '0', '0']
# command:store red
# 1
# -1148
# ['blue', 'red', '0', '0', '0', '0']
# command:restore white
# 0
# -1149
# ['0', 'red', '0', '0', '0', '0']
# command:restore red
# 1
# -1151
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -1152
# ['white', '0', '0', '0', '0', '0']
# command:store red
# 1
# -1154
# ['white', 'red', '0', '0', '0', '0']
# command:store blue
# 2
# -1156
# ['white', 'red', 'blue', '0', '0', '0']
# command:store blue
# 3
# -1159
# ['white', 'red', 'blue', 'blue', '0', '0']
# command:store white
# 4
# -1162
# ['white', 'red', 'blue', 'blue', 'white', '0']
# command:restore red
# 1
# -1164
# ['white', '0', 'blue', 'blue', 'white', '0']
# command:restore blue
# 2
# -1166
# ['white', '0', '0', 'blue', 'white', '0']
# command:restore blue
# 3
# -1169
# ['white', '0', '0', '0', 'white', '0']
# command:restore blue
# 0
# -1170
# ['0', '0', '0', '0', 'white', '0']
# command:store white
# 0
# -1171
# ['white', '0', '0', '0', 'white', '0']
# command:restore white
# 0
# -1172
# ['0', '0', '0', '0', 'white', '0']
# command:restore white
# 4
# -1175
# ['0', '0', '0', '0', '0', '0']
# command:restore white
# 0
# restorage not possible
# -1175
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -1176
# ['red', '0', '0', '0', '0', '0']
# command:store white
# 1
# -1178
# ['red', 'white', '0', '0', '0', '0']
# command:store blue
# 2
# -1180
# ['red', 'white', 'blue', '0', '0', '0']
# command:store blue
# 3
# -1183
# ['red', 'white', 'blue', 'blue', '0', '0']
# command:store red
# 4
# -1186
# ['red', 'white', 'blue', 'blue', 'red', '0']
# command:store white
# 5
# -1190
# ['red', 'white', 'blue', 'blue', 'red', 'white']
# command:restore red
# 0
# -1191
# ['0', 'white', 'blue', 'blue', 'red', 'white']
# command:restore red
# 4
# -1194
# ['0', 'white', 'blue', 'blue', '0', 'white']
# command:restore blue
# 2
# -1196
# ['0', 'white', '0', 'blue', '0', 'white']
# command:restore blue
# 3
# -1199
# ['0', 'white', '0', '0', '0', 'white']
# command:restore white
# 1
# -1201
# ['0', '0', '0', '0', '0', 'white']
# command:restore white
# 5
# -1205
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -1206
# ['blue', '0', '0', '0', '0', '0']
# command:store blue
# 3
# -1209
# ['blue', '0', '0', 'blue', '0', '0']
# command:store red
# 1
# -1211
# ['blue', 'red', '0', 'blue', '0', '0']
# command:store white
# 2
# -1213
# ['blue', 'red', 'white', 'blue', '0', '0']
# command:store red
# 4
# -1216
# ['blue', 'red', 'white', 'blue', 'red', '0']
# command:restore blue
# 0
# -1217
# ['0', 'red', 'white', 'blue', 'red', '0']
# command:restore red
# 1
# -1219
# ['0', '0', 'white', 'blue', 'red', '0']
# command:restore white
# 2
# -1221
# ['0', '0', '0', 'blue', 'red', '0']
# command:restore blue
# 3
# -1224
# ['0', '0', '0', '0', 'red', '0']
# command:store blue
# 0
# -1225
# ['blue', '0', '0', '0', 'red', '0']
# command:restore red
# 4
# -1228
# ['blue', '0', '0', '0', '0', '0']
# command:restore blue
# 0
# -1229
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -1230
# ['red', '0', '0', '0', '0', '0']
# command:store white
# 1
# -1232
# ['red', 'white', '0', '0', '0', '0']
# command:store blue
# 2
# -1234
# ['red', 'white', 'blue', '0', '0', '0']
# command:store red
# 3
# -1237
# ['red', 'white', 'blue', 'red', '0', '0']
# command:store blue
# 4
# -1240
# ['red', 'white', 'blue', 'red', 'blue', '0']
# command:restore red
# 0
# -1241
# ['0', 'white', 'blue', 'red', 'blue', '0']
# command:restore red
# 3
# -1244
# ['0', 'white', 'blue', '0', 'blue', '0']
# command:store red
# 0
# -1245
# ['red', 'white', 'blue', '0', 'blue', '0']
# command:restore blue
# 2
# -1247
# ['red', 'white', '0', '0', 'blue', '0']
# command:restore white
# 1
# -1249
# ['red', '0', '0', '0', 'blue', '0']
# command:restore red
# 0
# -1250
# ['0', '0', '0', '0', 'blue', '0']
# command:restore blue
# 4
# -1253
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -1254
# ['red', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -1256
# ['red', 'blue', '0', '0', '0', '0']
# command:store white
# 2
# -1258
# ['red', 'blue', 'white', '0', '0', '0']
# command:store red
# 3
# -1261
# ['red', 'blue', 'white', 'red', '0', '0']
# command:store blue
# 4
# -1264
# ['red', 'blue', 'white', 'red', 'blue', '0']
# command:store red
# 5
# -1268
# ['red', 'blue', 'white', 'red', 'blue', 'red']
# command:restore blue
# 1
# -1270
# ['red', '0', 'white', 'red', 'blue', 'red']
# command:restore white
# 2
# -1272
# ['red', '0', '0', 'red', 'blue', 'red']
# command:store red
# 1
# -1274
# ['red', 'red', '0', 'red', 'blue', 'red']
# command:store white
# 2
# -1276
# ['red', 'red', 'white', 'red', 'blue', 'red']
# command:restore blue
# 4
# -1279
# ['red', 'red', 'white', 'red', '0', 'red']
# command:restore white
# 2
# -1281
# ['red', 'red', '0', 'red', '0', 'red']
# command:restore red
# 0
# -1282
# ['0', 'red', '0', 'red', '0', 'red']
# command:restore red
# 1
# -1284
# ['0', '0', '0', 'red', '0', 'red']
# command:restore red
# 3
# -1287
# ['0', '0', '0', '0', '0', 'red']
# command:store red
# 0
# -1288
# ['red', '0', '0', '0', '0', 'red']
# command:store blue
# 1
# -1290
# ['red', 'blue', '0', '0', '0', 'red']
# command:store red
# 2
# -1292
# ['red', 'blue', 'red', '0', '0', 'red']
# command:store blue
# 3
# -1295
# ['red', 'blue', 'red', 'blue', '0', 'red']
# command:store red
# 4
# -1298
# ['red', 'blue', 'red', 'blue', 'red', 'red']
# command:restore red
# 0
# -1299
# ['0', 'blue', 'red', 'blue', 'red', 'red']
# command:restore red
# 2
# -1301
# ['0', 'blue', '0', 'blue', 'red', 'red']
# command:store white
# 0
# -1302
# ['white', 'blue', '0', 'blue', 'red', 'red']
# command:store red
# 2
# -1304
# ['white', 'blue', 'red', 'blue', 'red', 'red']
# command:restore red
# 2
# -1306
# ['white', 'blue', '0', 'blue', 'red', 'red']
# command:restore red
# 4
# -1309
# ['white', 'blue', '0', 'blue', '0', 'red']
# command:restore red
# 5
# -1313
# ['white', 'blue', '0', 'blue', '0', '0']
# command:restore blue
# 1
# -1315
# ['white', '0', '0', 'blue', '0', '0']
# command:restore white
# 0
# -1316
# ['0', '0', '0', 'blue', '0', '0']
# command:store white
# 0
# -1317
# ['white', '0', '0', 'blue', '0', '0']
# command:restore blue
# 3
# -1320
# ['white', '0', '0', '0', '0', '0']
# command:store white
# 1
# -1322
# ['white', 'white', '0', '0', '0', '0']
# command:store white
# 3
# -1325
# ['white', 'white', '0', 'white', '0', '0']
# command:store blue
# 2
# -1327
# ['white', 'white', 'blue', 'white', '0', '0']
# command:restore white
# 0
# -1328
# ['0', 'white', 'blue', 'white', '0', '0']
# command:restore white
# 1
# -1330
# ['0', '0', 'blue', 'white', '0', '0']
# command:restore white
# 3
# -1333
# ['0', '0', 'blue', '0', '0', '0']
# command:restore blue
# 2
# -1335
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -1336
# ['blue', '0', '0', '0', '0', '0']
# command:store red
# 1
# -1338
# ['blue', 'red', '0', '0', '0', '0']
# command:restore red
# 1
# -1340
# ['blue', '0', '0', '0', '0', '0']
# command:restore blue
# 0
# -1341
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -1342
# ['red', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -1344
# ['red', 'blue', '0', '0', '0', '0']
# command:store blue
# 3
# -1347
# ['red', 'blue', '0', 'blue', '0', '0']
# command:store blue
# 5
# -1351
# ['red', 'blue', '0', 'blue', '0', 'blue']
# command:restore red
# 0
# -1352
# ['0', 'blue', '0', 'blue', '0', 'blue']
# command:restore blue
# 1
# -1354
# ['0', '0', '0', 'blue', '0', 'blue']
# command:restore blue
# 3
# -1357
# ['0', '0', '0', '0', '0', 'blue']
# command:store blue
# 0
# -1358
# ['blue', '0', '0', '0', '0', 'blue']
# command:restore blue
# 0
# -1359
# ['0', '0', '0', '0', '0', 'blue']
# command:restore blue
# 5
# -1363
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -1364
# ['white', '0', '0', '0', '0', '0']
# command:store white
# 1
# -1366
# ['white', 'white', '0', '0', '0', '0']
# command:store red
# 2
# -1368
# ['white', 'white', 'red', '0', '0', '0']
# command:store white
# 3
# -1371
# ['white', 'white', 'red', 'white', '0', '0']
# command:restore white
# 0
# -1372
# ['0', 'white', 'red', 'white', '0', '0']
# command:restore red
# 2
# -1374
# ['0', 'white', '0', 'white', '0', '0']
# command:store white
# 0
# -1375
# ['white', 'white', '0', 'white', '0', '0']
# command:store white
# 0
# storage refused
# -1375
# ['white', 'white', '0', 'white', '0', '0']
# command:restore white
# 0
# -1376
# ['0', 'white', '0', 'white', '0', '0']
# command:store red
# 0
# -1377
# ['red', 'white', '0', 'white', '0', '0']
# command:store red
# 2
# -1379
# ['red', 'white', 'red', 'white', '0', '0']
# command:restore white
# 1
# -1381
# ['red', '0', 'red', 'white', '0', '0']
# command:restore white
# 3
# -1384
# ['red', '0', 'red', '0', '0', '0']
# command:restore red
# 0
# -1385
# ['0', '0', 'red', '0', '0', '0']
# command:restore white
# 0
# restorage not possible
# -1385
# ['0', '0', 'red', '0', '0', '0']
# command:store red
# 0
# -1386
# ['red', '0', 'red', '0', '0', '0']
# command:store red
# 3
# -1389
# ['red', '0', 'red', 'red', '0', '0']
# command:store white
# 1
# -1391
# ['red', 'white', 'red', 'red', '0', '0']
# command:store blue
# 4
# -1394
# ['red', 'white', 'red', 'red', 'blue', '0']
# command:restore blue
# 4
# -1397
# ['red', 'white', 'red', 'red', '0', '0']
# command:restore red
# 0
# -1398
# ['0', 'white', 'red', 'red', '0', '0']
# command:restore white
# 1
# -1400
# ['0', '0', 'red', 'red', '0', '0']
# command:restore red
# 2
# -1402
# ['0', '0', '0', 'red', '0', '0']
# command:restore red
# 3
# -1405
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -1406
# ['red', '0', '0', '0', '0', '0']
# command:store white
# 1
# -1408
# ['red', 'white', '0', '0', '0', '0']
# command:store red
# 2
# -1410
# ['red', 'white', 'red', '0', '0', '0']
# command:store red
# 3
# -1413
# ['red', 'white', 'red', 'red', '0', '0']
# command:store blue
# 4
# -1416
# ['red', 'white', 'red', 'red', 'blue', '0']
# command:restore blue
# 4
# -1419
# ['red', 'white', 'red', 'red', '0', '0']
# command:restore red
# 0
# -1420
# ['0', 'white', 'red', 'red', '0', '0']
# command:restore red
# 2
# -1422
# ['0', 'white', '0', 'red', '0', '0']
# command:store red
# 0
# -1423
# ['red', 'white', '0', 'red', '0', '0']
# command:store white
# 4
# -1426
# ['red', 'white', '0', 'red', 'white', '0']
# command:store blue
# 2
# -1428
# ['red', 'white', 'blue', 'red', 'white', '0']
# command:restore white
# 1
# -1430
# ['red', '0', 'blue', 'red', 'white', '0']
# command:restore red
# 0
# -1431
# ['0', '0', 'blue', 'red', 'white', '0']
# command:restore white
# 4
# -1434
# ['0', '0', 'blue', 'red', '0', '0']
# command:restore red
# 3
# -1437
# ['0', '0', 'blue', '0', '0', '0']
# command:store red
# 0
# -1438
# ['red', '0', 'blue', '0', '0', '0']
# command:store red
# 1
# -1440
# ['red', 'red', 'blue', '0', '0', '0']
# command:store red
# 3
# -1443
# ['red', 'red', 'blue', 'red', '0', '0']
# command:store white
# 4
# -1446
# ['red', 'red', 'blue', 'red', 'white', '0']
# command:store blue
# 5
# -1450
# ['red', 'red', 'blue', 'red', 'white', 'blue']
# command:restore white
# 4
# -1453
# ['red', 'red', 'blue', 'red', '0', 'blue']
# command:restore red
# 0
# -1454
# ['0', 'red', 'blue', 'red', '0', 'blue']
# command:restore blue
# 2
# ...
# command:store blue
# 3
# -24237
# ['blue', '0', '0', 'blue', '0', '0']
# command:store red
# 1
# -24239
# ['blue', 'red', '0', 'blue', '0', '0']
# command:store red
# 2
# -24241
# ['blue', 'red', 'red', 'blue', '0', '0']
# command:store red
# 4
# -24244
# ['blue', 'red', 'red', 'blue', 'red', '0']
# command:restore blue
# 0
# -24245
# ['0', 'red', 'red', 'blue', 'red', '0']
# command:restore red
# 1
# -24247
# ['0', '0', 'red', 'blue', 'red', '0']
# command:restore blue
# 3
# -24250
# ['0', '0', 'red', '0', 'red', '0']
# command:store blue
# 0
# -24251
# ['blue', '0', 'red', '0', 'red', '0']
# command:store blue
# 3
# -24254
# ['blue', '0', 'red', 'blue', 'red', '0']
# command:restore blue
# 0
# -24255
# ['0', '0', 'red', 'blue', 'red', '0']
# command:store red
# 0
# -24256
# ['red', '0', 'red', 'blue', 'red', '0']
# command:store blue
# 1
# -24258
# ['red', 'blue', 'red', 'blue', 'red', '0']
# command:restore red
# 0
# -24259
# ['0', 'blue', 'red', 'blue', 'red', '0']
# command:restore red
# 2
# -24261
# ['0', 'blue', '0', 'blue', 'red', '0']
# command:restore red
# 4
# -24264
# ['0', 'blue', '0', 'blue', '0', '0']
# command:restore blue
# 1
# -24266
# ['0', '0', '0', 'blue', '0', '0']
# command:store red
# 0
# -24267
# ['red', '0', '0', 'blue', '0', '0']
# command:restore red
# 0
# -24268
# ['0', '0', '0', 'blue', '0', '0']
# command:store blue
# 0
# -24269
# ['blue', '0', '0', 'blue', '0', '0']
# command:store blue
# 1
# -24271
# ['blue', 'blue', '0', 'blue', '0', '0']
# command:store red
# 2
# -24273
# ['blue', 'blue', 'red', 'blue', '0', '0']
# command:store red
# 4
# -24276
# ['blue', 'blue', 'red', 'blue', 'red', '0']
# command:restore blue
# 0
# -24277
# ['0', 'blue', 'red', 'blue', 'red', '0']
# command:restore blue
# 1
# -24279
# ['0', '0', 'red', 'blue', 'red', '0']
# command:restore red
# 2
# -24281
# ['0', '0', '0', 'blue', 'red', '0']
# command:store red
# 0
# -24282
# ['red', '0', '0', 'blue', 'red', '0']
# command:store red
# 1
# -24284
# ['red', 'red', '0', 'blue', 'red', '0']
# command:store red
# 5
# -24288
# ['red', 'red', '0', 'blue', 'red', 'red']
# command:restore blue
# 3
# -24291
# ['red', 'red', '0', '0', 'red', 'red']
# command:restore red
# 0
# -24292
# ['0', 'red', '0', '0', 'red', 'red']
# command:store blue
# 0
# -24293
# ['blue', 'red', '0', '0', 'red', 'red']
# command:restore red
# 1
# -24295
# ['blue', '0', '0', '0', 'red', 'red']
# command:restore red
# 4
# -24298
# ['blue', '0', '0', '0', '0', 'red']
# command:restore red
# 5
# -24302
# ['blue', '0', '0', '0', '0', '0']
# command:restore blue
# 0
# -24303
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -24304
# ['red', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -24306
# ['red', 'blue', '0', '0', '0', '0']
# command:restore red
# 0
# -24307
# ['0', 'blue', '0', '0', '0', '0']
# command:restore blue
# 1
# -24309
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -24310
# ['red', '0', '0', '0', '0', '0']
# command:store red
# 1
# -24312
# ['red', 'red', '0', '0', '0', '0']
# command:restore red
# 0
# -24313
# ['0', 'red', '0', '0', '0', '0']
# command:store blue
# 0
# -24314
# ['blue', 'red', '0', '0', '0', '0']
# command:restore red
# 1
# -24316
# ['blue', '0', '0', '0', '0', '0']
# command:store red
# 1
# -24318
# ['blue', 'red', '0', '0', '0', '0']
# command:restore blue
# 0
# -24319
# ['0', 'red', '0', '0', '0', '0']
# command:restore red
# 1
# -24321
# ['0', '0', '0', '0', '0', '0']
# command:store white
# 0
# -24322
# ['white', '0', '0', '0', '0', '0']
# command:store red
# 1
# -24324
# ['white', 'red', '0', '0', '0', '0']
# command:store white
# 3
# -24327
# ['white', 'red', '0', 'white', '0', '0']
# command:store red
# 2
# -24329
# ['white', 'red', 'red', 'white', '0', '0']
# command:restore red
# 1
# -24331
# ['white', '0', 'red', 'white', '0', '0']
# command:store blue
# 1
# -24333
# ['white', 'blue', 'red', 'white', '0', '0']
# command:store blue
# 4
# -24336
# ['white', 'blue', 'red', 'white', 'blue', '0']
# command:restore red
# 2
# -24338
# ['white', 'blue', '0', 'white', 'blue', '0']
# command:store white
# 5
# -24342
# ['white', 'blue', '0', 'white', 'blue', 'white']
# command:store blue
# 0
# -24343
# ['blue', 'blue', '0', 'white', 'blue', 'white']
# command:restore white
# 3
# -24346
# ['blue', 'blue', '0', '0', 'blue', 'white']
# command:restore blue
# 0
# -24347
# ['0', 'blue', '0', '0', 'blue', 'white']
# command:restore blue
# 1
# -24349
# ['0', '0', '0', '0', 'blue', 'white']
# command:restore blue
# 4
# -24352
# ['0', '0', '0', '0', '0', 'white']
# command:restore white
# 5
# -24356
# ['0', '0', '0', '0', '0', '0']
# command:restore white
# 0
# restorage not possible
# -24356
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -24357
# ['red', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -24359
# ['red', 'blue', '0', '0', '0', '0']
# command:store red
# 2
# -24361
# ['red', 'blue', 'red', '0', '0', '0']
# command:restore red
# 0
# -24362
# ['0', 'blue', 'red', '0', '0', '0']
# command:store red
# 0
# -24363
# ['red', 'blue', 'red', '0', '0', '0']
# command:store red
# 3
# -24366
# ['red', 'blue', 'red', 'red', '0', '0']
# command:store white
# 4
# -24369
# ['red', 'blue', 'red', 'red', 'white', '0']
# command:restore red
# 0
# -24370
# ['0', 'blue', 'red', 'red', 'white', '0']
# command:restore red
# 2
# -24372
# ['0', 'blue', '0', 'red', 'white', '0']
# command:restore red
# 3
# -24375
# ['0', 'blue', '0', '0', 'white', '0']
# command:restore blue
# 1
# -24377
# ['0', '0', '0', '0', 'white', '0']
# command:restore white
# 4
# -24380
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -24381
# ['blue', '0', '0', '0', '0', '0']
# command:store blue
# 3
# -24384
# ['blue', '0', '0', 'blue', '0', '0']
# command:store red
# 1
# -24386
# ['blue', 'red', '0', 'blue', '0', '0']
# command:store blue
# 5
# -24390
# ['blue', 'red', '0', 'blue', '0', 'blue']
# command:store red
# 2
# -24392
# ['blue', 'red', 'red', 'blue', '0', 'blue']
# command:restore red
# 1
# -24394
# ['blue', '0', 'red', 'blue', '0', 'blue']
# command:store white
# 1
# -24396
# ['blue', 'white', 'red', 'blue', '0', 'blue']
# command:store white
# 4
# -24399
# ['blue', 'white', 'red', 'blue', 'white', 'blue']
# command:restore red
# 2
# -24401
# ['blue', 'white', '0', 'blue', 'white', 'blue']
# command:restore blue
# 0
# -24402
# ['0', 'white', '0', 'blue', 'white', 'blue']
# command:restore white
# 1
# -24404
# ['0', '0', '0', 'blue', 'white', 'blue']
# command:restore blue
# 3
# -24407
# ['0', '0', '0', '0', 'white', 'blue']
# command:restore blue
# 5
# -24411
# ['0', '0', '0', '0', 'white', '0']
# command:restore white
# 4
# -24414
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -24415
# ['red', '0', '0', '0', '0', '0']
# command:store white
# 1
# -24417
# ['red', 'white', '0', '0', '0', '0']
# command:store white
# 3
# -24420
# ['red', 'white', '0', 'white', '0', '0']
# command:store red
# 2
# -24422
# ['red', 'white', 'red', 'white', '0', '0']
# command:store red
# 4
# -24425
# ['red', 'white', 'red', 'white', 'red', '0']
# command:store red
# 5
# -24429
# ['red', 'white', 'red', 'white', 'red', 'red']
# command:restore white
# 1
# -24431
# ['red', '0', 'red', 'white', 'red', 'red']
# command:store red
# 0
# storage refused
# -24431
# ['red', '0', 'red', 'white', 'red', 'red']
# command:restore white
# 3
# -24434
# ['red', '0', 'red', '0', 'red', 'red']
# command:restore red
# 0
# -24435
# ['0', '0', 'red', '0', 'red', 'red']
# command:restore red
# 2
# -24437
# ['0', '0', '0', '0', 'red', 'red']
# command:restore red
# 4
# -24440
# ['0', '0', '0', '0', '0', 'red']
# command:restore red
# 5
# -24444
# ['0', '0', '0', '0', '0', '0']
# command:restore red
# 0
# restorage not possible
# -24444
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -24445
# ['blue', '0', '0', '0', '0', '0']
# command:store blue
# 3
# -24448
# ['blue', '0', '0', 'blue', '0', '0']
# command:store red
# 1
# -24450
# ['blue', 'red', '0', 'blue', '0', '0']
# command:store blue
# 5
# -24454
# ['blue', 'red', '0', 'blue', '0', 'blue']
# command:restore red
# 1
# -24456
# ['blue', '0', '0', 'blue', '0', 'blue']
# command:store red
# 1
# -24458
# ['blue', 'red', '0', 'blue', '0', 'blue']
# command:restore blue
# 0
# -24459
# ['0', 'red', '0', 'blue', '0', 'blue']
# command:restore red
# 1
# -24461
# ['0', '0', '0', 'blue', '0', 'blue']
# command:store red
# 0
# -24462
# ['red', '0', '0', 'blue', '0', 'blue']
# command:store red
# 1
# -24464
# ['red', 'red', '0', 'blue', '0', 'blue']
# command:store blue
# 2
# -24466
# ['red', 'red', 'blue', 'blue', '0', 'blue']
# command:store blue
# 0
# -24467
# ['blue', 'red', 'blue', 'blue', '0', 'blue']
# command:restore red
# 1
# -24469
# ['blue', '0', 'blue', 'blue', '0', 'blue']
# command:restore red
# 0
# -24470
# ['0', '0', 'blue', 'blue', '0', 'blue']
# command:restore blue
# 2
# -24472
# ['0', '0', '0', 'blue', '0', 'blue']
# command:restore blue
# 3
# -24475
# ['0', '0', '0', '0', '0', 'blue']
# command:restore blue
# 5
# -24479
# ['0', '0', '0', '0', '0', '0']
# command:restore blue
# 0
# restorage not possible
# -24479
# ['0', '0', '0', '0', '0', '0']
# command:store blue
# 0
# -24480
# ['blue', '0', '0', '0', '0', '0']
# command:store blue
# 3
# -24483
# ['blue', '0', '0', 'blue', '0', '0']
# command:store red
# 1
# -24485
# ['blue', 'red', '0', 'blue', '0', '0']
# command:store white
# 2
# -24487
# ['blue', 'red', 'white', 'blue', '0', '0']
# command:store red
# 4
# -24490
# ['blue', 'red', 'white', 'blue', 'red', '0']
# command:store white
# 5
# -24494
# ['blue', 'red', 'white', 'blue', 'red', 'white']
# command:restore red
# 1
# -24496
# ['blue', '0', 'white', 'blue', 'red', 'white']
# command:store white
# 0
# -24497
# ['white', '0', 'white', 'blue', 'red', 'white']
# command:restore red
# 4
# -24500
# ['white', '0', 'white', 'blue', '0', 'white']
# command:restore blue
# 3
# -24503
# ['white', '0', 'white', '0', '0', 'white']
# command:restore blue
# 0
# -24504
# ['0', '0', 'white', '0', '0', 'white']
# command:restore white
# 2
# -24506
# ['0', '0', '0', '0', '0', 'white']
# command:restore white
# 5
# -24510
# ['0', '0', '0', '0', '0', '0']
# command:restore white
# 0
# restorage not possible
# -24510
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -24511
# ['red', '0', '0', '0', '0', '0']
# command:restore red
# 0
# -24512
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -24513
# ['red', '0', '0', '0', '0', '0']
# command:store red
# 1
# -24515
# ['red', 'red', '0', '0', '0', '0']
# command:store white
# 2
# -24517
# ['red', 'red', 'white', '0', '0', '0']
# command:store red
# 3
# -24520
# ['red', 'red', 'white', 'red', '0', '0']
# command:store red
# 5
# -24524
# ['red', 'red', 'white', 'red', '0', 'red']
# command:restore white
# 2
# -24526
# ['red', 'red', '0', 'red', '0', 'red']
# command:restore red
# 0
# -24527
# ['0', 'red', '0', 'red', '0', 'red']
# command:restore red
# 1
# -24529
# ['0', '0', '0', 'red', '0', 'red']
# command:restore red
# 3
# -24532
# ['0', '0', '0', '0', '0', 'red']
# command:restore red
# 5
# -24536
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -24537
# ['red', '0', '0', '0', '0', '0']
# command:store red
# 1
# -24539
# ['red', 'red', '0', '0', '0', '0']
# command:store red
# 3
# -24542
# ['red', 'red', '0', 'red', '0', '0']
# command:store white
# 2
# -24544
# ['red', 'red', 'white', 'red', '0', '0']
# command:restore white
# 2
# -24546
# ['red', 'red', '0', 'red', '0', '0']
# command:restore red
# 0
# -24547
# ['0', 'red', '0', 'red', '0', '0']
# command:restore red
# 1
# -24549
# ['0', '0', '0', 'red', '0', '0']
# command:restore red
# 3
# -24552
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -24553
# ['red', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -24555
# ['red', 'blue', '0', '0', '0', '0']
# command:store blue
# 3
# -24558
# ['red', 'blue', '0', 'blue', '0', '0']
# command:store red
# 2
# -24560
# ['red', 'blue', 'red', 'blue', '0', '0']
# command:store white
# 4
# -24563
# ['red', 'blue', 'red', 'blue', 'white', '0']
# command:restore red
# 0
# -24564
# ['0', 'blue', 'red', 'blue', 'white', '0']
# command:restore red
# 2
# -24566
# ['0', 'blue', '0', 'blue', 'white', '0']
# command:restore white
# 4
# -24569
# ['0', 'blue', '0', 'blue', '0', '0']
# command:restore blue
# 1
# -24571
# ['0', '0', '0', 'blue', '0', '0']
# command:store red
# 0
# -24572
# ['red', '0', '0', 'blue', '0', '0']
# command:store white
# 1
# -24574
# ['red', 'white', '0', 'blue', '0', '0']
# command:store blue
# 2
# -24576
# ['red', 'white', 'blue', 'blue', '0', '0']
# command:store blue
# 5
# -24580
# ['red', 'white', 'blue', 'blue', '0', 'blue']
# command:restore white
# 1
# -24582
# ['red', '0', 'blue', 'blue', '0', 'blue']
# command:restore blue
# 2
# -24584
# ['red', '0', '0', 'blue', '0', 'blue']
# command:restore blue
# 3
# -24587
# ['red', '0', '0', '0', '0', 'blue']
# command:restore red
# 0
# -24588
# ['0', '0', '0', '0', '0', 'blue']
# command:restore blue
# 5
# -24592
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -24593
# ['red', '0', '0', '0', '0', '0']
# command:store white
# 1
# -24595
# ['red', 'white', '0', '0', '0', '0']
# command:store white
# 3
# -24598
# ['red', 'white', '0', 'white', '0', '0']
# command:store red
# 2
# -24600
# ['red', 'white', 'red', 'white', '0', '0']
# command:store red
# 4
# -24603
# ['red', 'white', 'red', 'white', 'red', '0']
# command:restore red
# 0
# -24604
# ['0', 'white', 'red', 'white', 'red', '0']
# command:restore white
# 1
# -24606
# ['0', '0', 'red', 'white', 'red', '0']
# command:restore red
# 2
# -24608
# ['0', '0', '0', 'white', 'red', '0']
# command:restore red
# 4
# -24611
# ['0', '0', '0', 'white', '0', '0']
# command:store blue
# 0
# -24612
# ['blue', '0', '0', 'white', '0', '0']
# command:store blue
# 4
# -24615
# ['blue', '0', '0', 'white', 'blue', '0']
# command:store red
# 1
# -24617
# ['blue', 'red', '0', 'white', 'blue', '0']
# command:store red
# 2
# -24619
# ['blue', 'red', 'red', 'white', 'blue', '0']
# command:store red
# 5
# -24623
# ['blue', 'red', 'red', 'white', 'blue', 'red']
# command:restore blue
# 0
# -24624
# ['0', 'red', 'red', 'white', 'blue', 'red']
# command:restore white
# 3
# -24627
# ['0', 'red', 'red', '0', 'blue', 'red']
# command:restore red
# 1
# -24629
# ['0', '0', 'red', '0', 'blue', 'red']
# command:restore red
# 2
# -24631
# ['0', '0', '0', '0', 'blue', 'red']
# command:restore red
# 5
# -24635
# ['0', '0', '0', '0', 'blue', '0']
# command:restore blue
# 4
# -24638
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -24639
# ['red', '0', '0', '0', '0', '0']
# command:store white
# 1
# -24641
# ['red', 'white', '0', '0', '0', '0']
# command:restore red
# 0
# -24642
# ['0', 'white', '0', '0', '0', '0']
# command:store white
# 0
# -24643
# ['white', 'white', '0', '0', '0', '0']
# command:store blue
# 2
# -24645
# ['white', 'white', 'blue', '0', '0', '0']
# command:store red
# 3
# -24648
# ['white', 'white', 'blue', 'red', '0', '0']
# command:store white
# 5
# -24652
# ['white', 'white', 'blue', 'red', '0', 'white']
# command:restore red
# 3
# -24655
# ['white', 'white', 'blue', '0', '0', 'white']
# command:restore blue
# 2
# -24657
# ['white', 'white', '0', '0', '0', 'white']
# command:restore white
# 0
# -24658
# ['0', 'white', '0', '0', '0', 'white']
# command:store red
# 0
# -24659
# ['red', 'white', '0', '0', '0', 'white']
# command:store red
# 2
# -24661
# ['red', 'white', 'red', '0', '0', 'white']
# command:restore red
# 0
# -24662
# ['0', 'white', 'red', '0', '0', 'white']
# command:store red
# 0
# -24663
# ['red', 'white', 'red', '0', '0', 'white']
# command:store blue
# 3
# -24666
# ['red', 'white', 'red', 'blue', '0', 'white']
# command:store blue
# 4
# -24669
# ['red', 'white', 'red', 'blue', 'blue', 'white']
# command:restore white
# 1
# -24671
# ['red', '0', 'red', 'blue', 'blue', 'white']
# command:restore red
# 0
# -24672
# ['0', '0', 'red', 'blue', 'blue', 'white']
# command:restore red
# 2
# -24674
# ['0', '0', '0', 'blue', 'blue', 'white']
# command:store red
# 0
# -24675
# ['red', '0', '0', 'blue', 'blue', 'white']
# command:store red
# 1
# -24677
# ['red', 'red', '0', 'blue', 'blue', 'white']
# command:restore white
# 5
# -24681
# ['red', 'red', '0', 'blue', 'blue', '0']
# command:restore blue
# 3
# -24684
# ['red', 'red', '0', '0', 'blue', '0']
# command:restore red
# 0
# -24685
# ['0', 'red', '0', '0', 'blue', '0']
# command:restore blue
# 4
# -24688
# ['0', 'red', '0', '0', '0', '0']
# command:store red
# 0
# -24689
# ['red', 'red', '0', '0', '0', '0']
# command:store white
# 2
# -24691
# ['red', 'red', 'white', '0', '0', '0']
# command:restore red
# 0
# -24692
# ['0', 'red', 'white', '0', '0', '0']
# command:restore white
# 2
# -24694
# ['0', 'red', '0', '0', '0', '0']
# command:restore red
# 1
# -24696
# ['0', '0', '0', '0', '0', '0']
# command:store red
# 0
# -24697
# ['red', '0', '0', '0', '0', '0']
# command:store blue
# 1
# -24699
# ['red', 'blue', '0', '0', '0', '0']
# command:store red
# 2
# -24701
# ['red', 'blue', 'red', '0', '0', '0']
# command:store red
# 3
# -24704
# ['red', 'blue', 'red', 'red', '0', '0']
# command:store red
# 5
# -24708
# ['red', 'blue', 'red', 'red', '0', 'red']
# command:store white
# 4
# -24711
# ['red', 'blue', 'red', 'red', 'white', 'red']
# command:restore white
# 4
# -24714
# ['red', 'blue', 'red', 'red', '0', 'red']
# command:restore red
# 0
# -24715
# ['0', 'blue', 'red', 'red', '0', 'red']
# command:restore blue
# 1
# -24717
# ['0', '0', 'red', 'red', '0', 'red']
# command:restore red
# 2
# -24719
# ['0', '0', '0', 'red', '0', 'red']
# command:restore red
# 3
# -24722
# ['0', '0', '0', '0', '0', 'red']
# command:restore red
# 5
# -24726
# ['0', '0', '0', '0', '0', '0']
# TOTAL COST:    -24726
# 204
# 136
# 0:02:18.119098
